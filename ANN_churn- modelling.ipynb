# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Churn_Modelling - Churn_Modelling.csv')

# %%
dataset.shape
# Out:
# (10000, 14)

# %%
dataset.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
dataset.drop(columns = ['RowNumber','CustomerId','Surname'],inplace=True)

# %%
dataset.shape
# Out:
# (10000, 11)

# %%
dataset['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
dataset['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
#Using one-hot encoding
df = pd.get_dummies(dataset,columns=['Geography','Gender'],drop_first= True)

# %%
df
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                  1        101348.88       1              False
# 1                  1        112542.58       0              False
# 2                  0        113931.57       1              False
# 3                  0         93826.63       0              False
# 4                  1         79084.10       0              False
# ...              ...              ...     ...                ...
# 9995               0         96270.64       0              False
# 9996               1        101699.77       0              False
# 9997               1         42085.58       1              False
# 9998               0         92888.52       1               True
# 9999               0         38190.78       0              False
#
#       Geography_Spain  Gender_Male
# 0               False        False
# 1                True        False
# 2               False        False
# 3               False        False
# 4                True        False
# ...               ...          ...
# 9995            False         True
# 9996            False         True
# 9997            False        False
# 9998            False         True
# 9999            False        False
#
# [10000 rows x 12 columns]

# %%
# split dataset into X and Y

X = df.drop(columns=['Exited'])
y = df['Exited'].values

# %%
# Split the X and Y Dataset into the Training set and Test set

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# Perform Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Build Artificial Neural Network The first step is-

import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Initialize the Artificial Neural Network

classifier1 = Sequential()

# %%
# Add the input layer and the first hidden layer

classifier1.add(Dense(3, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Add the second hidden layer

classifier1.add(Dense(3, kernel_initializer = 'uniform', activation = 'relu'))

# %%
# Add the output layer

classifier1.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
# Train the ANN
# 1 Compile the ANN

from tensorflow.keras.optimizers import Adam

#optimizer = Adam(learning_rate=0.01)  # you can set your desired learning rate here
classifier1.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss',   # Monitor validation loss
                               patience=10,          # Number of epochs with no improvement before stopping
                               restore_best_weights=True,  # Restore the best weights after stopping
                               verbose=1)

# %%
# Fit the ANN to the Training set

history = classifier1.fit(X_train, y_train,
                    epochs=100,                # Train for up to 100 epochs
                    batch_size=64,             # Batch size for each update
                    validation_data=(X_test, y_test), # Use validation data for evaluation
                    callbacks=[early_stopping],  # Include early stopping callback
                    verbose=1)  # Print progress during training
# Out:
# Epoch 1/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7957 - loss: 0.6815 - val_accuracy: 0.7975 - val_loss: 0.6236
# Epoch 2/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7922 - loss: 0.5863 - val_accuracy: 0.7975 - val_loss: 0.4870
# Epoch 3/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7963 - loss: 0.4724 - val_accuracy: 0.7975 - val_loss: 0.4486
# Epoch 4/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8004 - loss: 0.4371 - val_accuracy: 0.7975 - val_loss: 0.4404
# Epoch 5/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7984 - loss: 0.4338 - val_accuracy: 0.7975 - val_loss: 0.4368
# Epoch 6/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7920 - loss: 0.4374 - val_accuracy: 0.7975 - val_loss: 0.4345
# Epoch 7/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7977 - loss: 0.4306 - val_accuracy: 0.7975 - val_loss: 0.4332
# Epoch 8/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7947 - loss: 0.4329 - val_accuracy: 0.7975 - val_loss: 0.4322
# Epoch 9/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7975 - loss: 0.4302 - val_accuracy: 0.7975 - val_loss: 0.4316
# Epoch 10/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
# Epoch 80/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8366 - loss: 0.4030 - val_accuracy: 0.8385 - val_loss: 0.4032
# Epoch 81/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8316 - loss: 0.4121 - val_accuracy: 0.8390 - val_loss: 0.4027
# Epoch 82/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8346 - loss: 0.4050 - val_accuracy: 0.8395 - val_loss: 0.4030
# Epoch 83/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8385 - loss: 0.3980 - val_accuracy: 0.8405 - val_loss: 0.4032
# Epoch 84/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8382 - loss: 0.4010 - val_accuracy: 0.8395 - val_loss: 0.4032
# Epoch 85/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8351 - loss: 0.4067 - val_accuracy: 0.8400 - val_loss: 0.4026
# Epoch 86/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8288 - loss: 0.4104 - val_accuracy: 0.8410 - val_loss: 0.4026
# Epoch 87/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8301 - loss: 0.4090 - val_accuracy: 0.8400 - val_loss: 0.4026
# Epoch 88/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8367 - loss: 0.4037 - val_accuracy: 0.8400 - val_loss: 0.4026
# Epoch 89/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8323 - loss: 0.4038 - val_accuracy: 0.8390 - val_loss: 0.4022
# Epoch 90/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8410 - loss: 0.3978 - val_accuracy: 0.8405 - val_loss: 0.4020
# Epoch 91/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8253 - loss: 0.4227 - val_accuracy: 0.8390 - val_loss: 0.4018
# Epoch 92/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8259 - loss: 0.4203 - val_accuracy: 0.8400 - val_loss: 0.4019
# Epoch 93/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8364 - loss: 0.3964 - val_accuracy: 0.8405 - val_loss: 0.4019
# Epoch 94/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8347 - loss: 0.4093 - val_accuracy: 0.8400 - val_loss: 0.4016
# Epoch 95/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8357 - loss: 0.4054 - val_accuracy: 0.8400 - val_loss: 0.4021
# Epoch 96/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8376 - loss: 0.3989 - val_accuracy: 0.8410 - val_loss: 0.4017
# Epoch 97/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8336 - loss: 0.4014 - val_accuracy: 0.8395 - val_loss: 0.4013
# Epoch 98/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8329 - loss: 0.4132 - val_accuracy: 0.8390 - val_loss: 0.4015
# Epoch 99/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8346 - loss: 0.3996 - val_accuracy: 0.8405 - val_loss: 0.4012
# Epoch 100/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8313 - loss: 0.4076 - val_accuracy: 0.8390 - val_loss: 0.4014
# Restoring model weights from the end of the best epoch: 99.

# %%
classifier1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 3)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 158 (636.00 B)
#  Trainable params: 52 (208.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 106 (428.00 B)

# %%
loss, accuracy = classifier1.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8410 - loss: 0.3907
# Test Loss: 0.40123242139816284
# Test Accuracy: 0.840499997138977

# %%
# Step 10: Plot training history (loss and accuracy)
# Plot the training and validation loss over epochs
plt.figure(figsize=(12, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Predict the Test Set Results
y_pred = classifier1.predict(X_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred
# Out:
# array([[0.24096018],
#        [0.31990963],
#        [0.18910882],
#        ...,
#        [0.17618476],
#        [0.13684916],
#        [0.13881059]], dtype=float32)

# %%
y_pred = (y_pred > 0.5)
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
# Make the Confusion Matrix

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
print("\n")
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy Score:", accuracy)
print("\n")

report = classification_report(y_test, y_pred)
print("Classification Report:")
print(report)
# Out:
# Confusion Matrix:
# [[1552   43]
#  [ 276  129]]
#
#
# Accuracy Score: 0.8405
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91      1595
#            1       0.75      0.32      0.45       405
#
#     accuracy                           0.84      2000
#    macro avg       0.80      0.65      0.68      2000
# weighted avg       0.83      0.84      0.81      2000

# %%
from tensorflow import keras
from tensorflow.keras.utils import plot_model

# Generate the visualization of the model's architecture
plot_model(classifier1, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)

from IPython.display import Image
Image('model_architecture.png')
